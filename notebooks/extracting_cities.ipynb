# %% [markdown]
# # Instructions

# %% [markdown]
# To run this notebook you will need to:
# 1. Download Ollam from [here](https://ollama.com/)
# 2. Go to your terminal and type: `ollama pull llama3` to download llama3 model in your local computer.

# %% [markdown]
# ## Imports

# %%
import subprocess
import re
import ast
import pandas as pd

# %% [markdown]
# ## Function to extract location name

# %%
def extract_locations_from_text(text, model="llama3"):
    """
    Directly extracts the city name from the given court text.

    Parameters
    ----------
    text : str
        The court text to analyze.
    model : str, optional
        The name of the language model to use (default is "llama3").

    Returns
    -------
    str
        The extracted city name, or 'NA' if no location is found.
    """
    prompt = f"""
You are a legal assistant. Identify the city where the case was heard from the following court text.

Instructions:
- Extract the city where the case was heard.
- Just provide the city name, nothing else.
- If no location is found, return NA

Court Text:
{text}
"""
    result = subprocess.run(
        ["ollama", "run", model],
        input=prompt.encode(),
        stdout=subprocess.PIPE,
        stderr=subprocess.PIPE
    )
    
    output = result.stdout.decode().strip()
    
    return output if output else "NA"

def extract_locations_from_dataframe(df, startline, endline, text_column="unofficial_text", model="llama3"):
    """
    Extract city names from a DataFrame containing court texts.

    Parameters
    ----------
    df : pandas.DataFrame
        The DataFrame containing court text data.
    startline : int
        The starting line number of the text to consider.
    endline : int
        The ending line number of the text to consider.
    text_column : str, optional
        The column in `df` that contains the court text (default is "unofficial_text").
    model : str, optional
        The language model to use (default is "llama3").

    Returns
    -------
    pandas.DataFrame
        A copy of the input DataFrame with an additional 'locations' column containing extracted city names.
    """
    df = df.copy()

    def extract_slice_and_location(text):
        lines = text.splitlines()
        selected_text = "\n".join(lines[startline:endline])
        return extract_locations_from_text(selected_text, model=model)

    df["locations"] = df[text_column].apply(extract_slice_and_location)

    return df

# %% [markdown]
# ## FCA Data

# %%
FCA = pd.read_csv("../data/processed/FCA_judges.csv")
FCA
# Out:
#     Unnamed: 0      citation dataset  year language document_date  \
# 0            0  2014 FCA 113     FCA  2014       en    2014-05-02
# 1            1  2014 FCA 114     FCA  2014       en    2014-05-02
# 2            2  2014 FCA 126     FCA  2014       en    2014-05-14
# 3            3  2014 FCA 157     FCA  2014       en    2014-06-10
# 4            4  2014 FCA 160     FCA  2014       en    2014-06-12
# ..         ...           ...     ...   ...      ...           ...
# 94          94   2023 FCA 36     FCA  2023       en    2023-02-16
# 95          95  2024 FCA 165     FCA  2024       en    2024-10-08
# 96          96  2024 FCA 174     FCA  2024       en    2024-10-24
# 97          97  2020 CAF 126     FCA  2020       fr    2020-07-28
# 98          98   2024 CAF 49     FCA  2024       fr    2024-03-18
#
#                                            source_url  \
# 0   https://decisions.fca-caf.gc.ca/fca-caf/decisi...
# 1   https://decisions.fca-caf.gc.ca/fca-caf/decisi...
# 2   https://decisions.fca-caf.gc.ca/fca-caf/decisi...
# 3   https://decisions.fca-caf.gc.ca/fca-caf/decisi...
# 4   https://decisions.fca-caf.gc.ca/fca-caf/decisi...
# ..                                                ...
# 94  https://decisions.fca-caf.gc.ca/fca-caf/decisi...
# 95  https://decisions.fca-caf.gc.ca/fca-caf/decisi...
# 96  https://decisions.fca-caf.gc.ca/fca-caf/decisi...
# 97  https://decisions.fca-caf.gc.ca/fca-caf/decisi...
# 98  https://decisions.fca-caf.gc.ca/fca-caf/decisi...
#
#                                       unofficial_text  \
# 0   Kanthasamy v. Canada (Citizenship and Immigrat...
# 1   Lemus v. Canada (Citizenship and Immigration)\...
# 2   Kinsel v. Canada (Citizenship and Immigration)...
# 3   Sanchez v. Canada (Citizenship and Immigration...
# 4   Canada (Citizenship and Immigration) v. Savin\...
# ..                                                ...
# 94  Lukács v. Canada (Citizenship and Immigration)...
# 95  Nanhar v. Canada (Citizenship and Immigration)...
# 96  Li v. Canada (Citizenship and Immigration)\nCo...
# 97  Canada (Citoyenneté et Immigration) c. Solmaz\...
# 98  Mvana c. Canada (Citoyenneté et Immigration)\n...
#
#                                inadmissibility_reason  \
# 0                                         ['refugee']
# 1                                         ['refugee']
# 2   ['security', 'human_rights', 'serious_criminal...
# 3              ['serious_criminality', 'criminality']
# 4                                    ['human_rights']
# ..                                                ...
# 94                                        ['refugee']
# 95                                        ['refugee']
# 96  ['human_rights', 'serious_criminality', 'crimi...
# 97                                        ['refugee']
# 98                                        ['refugee']
#
#                                   judges
# 0       ['BLAIS', 'SHARLOW', 'STRA TAS']
# 1       ['BLAIS', 'SHARLOW', 'STRA TAS']
# 2           ['Dawson', 'Trudel', 'Near']
# 3          ['Nadon', 'Stratas', 'Scott']
# 4    ['Gauthier', 'Mainville', 'Boivin']
# ..                                   ...
# 94     ['PELLETIER', 'WOODS', 'ROUSSEL']
# 95       ['Webb', 'Mactavish', 'Walker']
# 96      ['Stratas', 'Boivin', 'Heckman']
# 97  ['Boivin', 'De Montigny', 'Leblanc']
# 98     ['Montigny', 'Boivin', 'Rousset']
#
# [99 rows x 10 columns]

# %%
FCA_city = extract_locations_from_dataframe(FCA, 20, 55,  text_column="unofficial_text", model="llama3")
FCA_city
# Out:
#     Unnamed: 0      citation dataset  year language document_date  \
# 0            0  2014 FCA 113     FCA  2014       en    2014-05-02
# 1            1  2014 FCA 114     FCA  2014       en    2014-05-02
# 2            2  2014 FCA 126     FCA  2014       en    2014-05-14
# 3            3  2014 FCA 157     FCA  2014       en    2014-06-10
# 4            4  2014 FCA 160     FCA  2014       en    2014-06-12
# ..         ...           ...     ...   ...      ...           ...
# 94          94   2023 FCA 36     FCA  2023       en    2023-02-16
# 95          95  2024 FCA 165     FCA  2024       en    2024-10-08
# 96          96  2024 FCA 174     FCA  2024       en    2024-10-24
# 97          97  2020 CAF 126     FCA  2020       fr    2020-07-28
# 98          98   2024 CAF 49     FCA  2024       fr    2024-03-18
#
#                                            source_url  \
# 0   https://decisions.fca-caf.gc.ca/fca-caf/decisi...
# 1   https://decisions.fca-caf.gc.ca/fca-caf/decisi...
# 2   https://decisions.fca-caf.gc.ca/fca-caf/decisi...
# 3   https://decisions.fca-caf.gc.ca/fca-caf/decisi...
# 4   https://decisions.fca-caf.gc.ca/fca-caf/decisi...
# ..                                                ...
# 94  https://decisions.fca-caf.gc.ca/fca-caf/decisi...
# 95  https://decisions.fca-caf.gc.ca/fca-caf/decisi...
# 96  https://decisions.fca-caf.gc.ca/fca-caf/decisi...
# 97  https://decisions.fca-caf.gc.ca/fca-caf/decisi...
# 98  https://decisions.fca-caf.gc.ca/fca-caf/decisi...
#
#                                       unofficial_text  \
# 0   Kanthasamy v. Canada (Citizenship and Immigrat...
# 1   Lemus v. Canada (Citizenship and Immigration)\...
# 2   Kinsel v. Canada (Citizenship and Immigration)...
# 3   Sanchez v. Canada (Citizenship and Immigration...
# 4   Canada (Citizenship and Immigration) v. Savin\...
# ..                                                ...
# 94  Lukács v. Canada (Citizenship and Immigration)...
# 95  Nanhar v. Canada (Citizenship and Immigration)...
# 96  Li v. Canada (Citizenship and Immigration)\nCo...
# 97  Canada (Citoyenneté et Immigration) c. Solmaz\...
# 98  Mvana c. Canada (Citoyenneté et Immigration)\n...
#
#                                inadmissibility_reason  \
# 0                                         ['refugee']
# 1                                         ['refugee']
# 2   ['security', 'human_rights', 'serious_criminal...
# 3              ['serious_criminality', 'criminality']
# 4                                    ['human_rights']
# ..                                                ...
# 94                                        ['refugee']
# 95                                        ['refugee']
# 96  ['human_rights', 'serious_criminality', 'crimi...
# 97                                        ['refugee']
# 98                                        ['refugee']
#
#                                   judges  locations
# 0       ['BLAIS', 'SHARLOW', 'STRA TAS']    Toronto
# 1       ['BLAIS', 'SHARLOW', 'STRA TAS']    Toronto
# 2           ['Dawson', 'Trudel', 'Near']  Vancouver
# 3          ['Nadon', 'Stratas', 'Scott']  Vancouver
# 4    ['Gauthier', 'Mainville', 'Boivin']   Montréal
# ..                                   ...        ...
# 94     ['PELLETIER', 'WOODS', 'ROUSSEL']     Ottawa
# 95       ['Webb', 'Mactavish', 'Walker']     Ottawa
# 96      ['Stratas', 'Boivin', 'Heckman']     Ottawa
# 97  ['Boivin', 'De Montigny', 'Leblanc']     Ottawa
# 98     ['Montigny', 'Boivin', 'Rousset']   Montréal
#
# [99 rows x 11 columns]

# %%
FCA_city['locations'].value_counts()
# Out:
# locations
# Ottawa        36
# Toronto       33
# Vancouver     11
# Montréal       8
# Winnipeg       4
# Montreal       3
# Calgary        2
# Saint Paul     1
# NA             1
# Name: count, dtype: int64

# %%
FCA_city.to_csv("../data/processed/FCA_city.csv")

# %% [markdown]
# ## FC Data

# %%
FC = pd.read_csv("../data/processed/FC_Judges.csv")
FC
# Out:
#       Unnamed: 0      citation dataset  year language document_date  \
# 0          11922     2014 FC 1      FC  2014       en    2014-01-02
# 1          11930  2014 FC 1008      FC  2014       en    2014-10-22
# 2          11933  2014 FC 1011      FC  2014       en    2014-10-23
# 3          11934  2014 FC 1012      FC  2014       en    2014-10-23
# 4          11935  2014 FC 1015      FC  2014       en    2014-10-24
# ...          ...           ...     ...   ...      ...           ...
# 4826       23170   2022 CF 882      FC  2022       fr    2022-06-16
# 4827       23173  2023 CF 1619      FC  2023       fr    2023-12-01
# 4828       23177   2024 CF 151      FC  2024       fr    2024-01-30
# 4829       23178   2024 CF 327      FC  2024       fr    2024-02-28
# 4830       23180   2024 CF 911      FC  2024       fr    2024-06-13
#
#                                              source_url  \
# 0     https://decisions.fct-cf.gc.ca/fc-cf/decisions...
# 1     https://decisions.fct-cf.gc.ca/fc-cf/decisions...
# 2     https://decisions.fct-cf.gc.ca/fc-cf/decisions...
# 3     https://decisions.fct-cf.gc.ca/fc-cf/decisions...
# 4     https://decisions.fct-cf.gc.ca/fc-cf/decisions...
# ...                                                 ...
# 4826  https://decisions.fct-cf.gc.ca/fc-cf/decisions...
# 4827  https://decisions.fct-cf.gc.ca/fc-cf/decisions...
# 4828  https://decisions.fct-cf.gc.ca/fc-cf/decisions...
# 4829  https://decisions.fct-cf.gc.ca/fc-cf/decisions...
# 4830  https://decisions.fct-cf.gc.ca/fc-cf/decisions...
#
#                                         unofficial_text  \
# 0     Telus Communications Company v. Canada (Attorn...
# 1     Bautista v. Canada (Citizenship and Immigratio...
# 2     Canada (Public Safety and Emergency Preparedne...
# 3     Po v. Canada (Citizenship and Immigration)\nCo...
# 4     Gordon v. Canada (Citizenship and Immigration)...
# ...                                                 ...
# 4826  Jules c. Canada (Citoyenneté et Immigration)\n...
# 4827  Salhi c. Canada (Citoyenneté et Immigration)\n...
# 4828  Salazar Vargas c. Canada (Citoyenneté et Immig...
# 4829  Rashidian c. Canada (Procureur général)\nBase ...
# 4830  Canada (Citoyenneté et Immigration) c. Asphall...
#
#                                  inadmissibility_reason  \
# 0     ['human_rights', 'serious_criminality', 'crimi...
# 1                                 ['misrepresentation']
# 2                                    ['non_compliance']
# 3                                      ['human_rights']
# 4                 ['human_rights', 'misrepresentation']
# ...                                                 ...
# 4826  ['human_rights', 'serious_criminality', 'crimi...
# 4827             ['serious_criminality', 'criminality']
# 4828             ['serious_criminality', 'criminality']
# 4829                                   ['human_rights']
# 4830              ['human_rights', 'misrepresentation']
#
#                           judges
# 0                 ['Strickland']
# 1                      ['Diner']
# 2          ['Shore', 'Gauthier']
# 3             ['Tremblay-Lamer']
# 4                      ['Locke']
# ...                          ...
# 4826                ['St-Louis']
# 4827                 ['Azmudeh']
# 4828                ['Heneghan']
# 4829  ['Ngo', 'Tabib', 'Steele']
# 4830              ['Fothergill']
#
# [4831 rows x 10 columns]

# %%
FC_city = extract_locations_from_dataframe(FCA, 10, 25,  text_column="unofficial_text", model="llama3")
FC_city

# %%
FC_city['locations'].value_counts()

# %%
FC_city.to_csv("../data/processed/FC_city.csv")
